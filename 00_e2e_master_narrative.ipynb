# %% [markdown]
# # End-to-End Narrative Notebook
#
# This root notebook is narrative-first for urban planning and policy audiences.

# %%
PROJECT_NAME = "PLAN 6068 Rooftop PV Panel-Row Extraction"
PROJECT_NAME
